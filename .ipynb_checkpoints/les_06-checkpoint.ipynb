# %%
from scipy.stats import norm
import numpy as np
norm.cdf(1.96)
# Out:
# 0.9750021048517795

# %%
norm.ppf(0.9750021048517795)
# Out:
# 1.959999999999999

# %%
import pylab
import scipy.stats as stats
import random
arr=np.array([1.2,1.6,1.8,1.8,2.5,2.6,3,3.3])

# %%
stats.probplot(arr,dist="norm",plot=pylab)
pylab.show()

# %%
arrr=np.array([random.random() for i in range(10000)])
stats.probplot(arrr,dist="norm",plot=pylab)
pylab.show()

# %%
arrr
# Out:
# array([962.83444392, 242.10674959, 510.3269762 , ...,  35.97798423,
#        718.60223787, 111.29095591])

# %%
from random import randint
# len_mass = int(input()) # задаем длину массива(списка из списков)
# len_elem = int(input() # количество элементов в элементе(подсписке)
a,b = -10,10 # диапазон, можно задавать через input()
mass = [np.random.poisson(10000) for _ in range(100000)]
stats.probplot(mass,dist="norm",plot=pylab)
pylab.show()

# %%
from random import randint
# len_mass = int(input()) # задаем длину массива(списка из списков)
# len_elem = int(input() # количество элементов в элементе(подсписке)
a,b = -10,10 # диапазон, можно задавать через input()
mass = [np.random.normal(1.5, 4.0) for _ in range(10000)]
stats.probplot(mass,dist="norm",plot=pylab)
pylab.show()

# %%
from random import randint
# len_mass = int(input()) # задаем длину массива(списка из списков)
# len_elem = int(input() # количество элементов в элементе(подсписке)
a,b = -10,10 # диапазон, можно задавать через input()
mass = [np.random.normal() for _ in range(10000)]
stats.probplot(mass,dist="norm",plot=pylab)
pylab.show()

# %%
from random import randint
# len_mass = int(input()) # задаем длину массива(списка из списков)
# len_elem = int(input() # количество элементов в элементе(подсписке)
a,b = -10,10 # диапазон, можно задавать через input()
mass = np.random.normal(size=50000)
stats.probplot(mass,dist="norm",plot=pylab)
pylab.show()

# %%
import scipy

def genData(samples = 20, mean = 333.8, sd = 3.38):
    bl = scipy.stats.norm.rvs(loc = mean, scale = sd, size = samples)
    return [np.mean(bl), np.std(bl, ddof = 1)]

means = {}
sds = {}

n = 500 # 50000

for size in range(5,21):
    x = [genData(size, mean = 0, sd = 1) for x in range(n)]
    means[size] = map(lambda d: d[0], x)
    sds[size] = map(lambda d: d[1], x)

genData()
# Out:
# [334.49361114658666, 3.9132537631660402]
