# %% [markdown]
# # Все ответы вероятности даны в %, так мне легче осознать результат (т.е. *100).

# %% [markdown]
#     Даны значения зарплат из выборки выпускников: 100, 80, 75, 77, 89, 33, 45, 25, 65, 17, 30, 24, 57, 55, 70, 75, 65, 84, 90, 150. Посчитать (желательно без использования статистических методов наподобие std, var, mean) среднее арифметическое, среднее квадратичное отклонение, смещенную и несмещенную оценки дисперсий для данной выборки.

# %%
import numpy as np
m=[100, 80, 75, 77, 89, 33, 45, 25, 65, 17, 30, 24, 57, 55, 70, 75, 65, 84, 90, 150]
msr = sum(m)/len(m) # среднее
print('среднее',msr)
# np.std(m)
# np.var(m,ddof=1)
summ=0
for x in m:
    summ=summ+(x-msr)**2
S=summ/(len(m)-1)
print('смещенная',summ/(len(m)))
print('несмещенная',summ/(len(m)-1))
# В чем прикол найти одно и тоже?
# "среднее квадратичное отклонение, смещенную и несмещенную оценки дисперсий"
# Out:
# среднее 65.3
# смещенная 950.11
# несмещенная 1000.1157894736842

# %% [markdown]
# В первом ящике находится 8 мячей, из которых 5 - белые. Во втором ящике - 12 мячей, из которых 5 белых. Из первого ящика вытаскивают случайным образом два мяча, из второго - 4. Какова вероятность того, что 3 мяча белые?

# %%
from math import factorial
import math
from decimal import *
def combinations(n, k):
    return int(factorial(n) / (factorial(k) * factorial(n - k)))

p1 = (combinations(5,2)/combinations(8,2) * combinations(5,1)/combinations(12,1)*combinations(7,3)/combinations(12,3))# бб-бччч
p2 = (combinations(3,2)/combinations(8,2) * combinations(5,3)/combinations(12,3)*combinations(7,1)/combinations(12,1)) # чч-бббч 
p3 = (combinations(5,1)/combinations(8,1)*combinations(3,1)/combinations(8,1) * combinations(5,2)/combinations(12,2)*combinations(7,2)/combinations(12,2))# бч-ббчч
print(p1)
print(p2)
print(p3)
print('три шара белые: ',p1+p2+p3)
# Out:
# 0.023674242424242424
# 0.0028409090909090906
# 0.011299070247933887
# три шара белые:  0.0378142217630854

# %% [markdown]
#  На соревновании по биатлону один из трех спортсменов стреляет и попадает в мишень. Вероятность попадания для первого спортсмена равна 0.9, для второго — 0.8, для третьего — 0.6. Найти вероятность того, что выстрел произведен: a). первым спортсменом б). вторым спортсменом в). третьим спортсменом.

# %%
p1=0.9
p2=0.8
p3=0.6
n=1
p=p1+p2+p3
print('первый спортсмен вероятность',p1/p)
print('первый спортсмен вероятность',p2/p)
print('первый спортсмен вероятность',p3/p)
print('проверка',p1/p+p2/p+p3/p)
# Out:
# первый спортсмен вероятность 0.3913043478260869
# первый спортсмен вероятность 0.34782608695652173
# первый спортсмен вероятность 0.26086956521739124
# проверка 0.9999999999999999

# %% [markdown]
#  В университет на факультеты A и B поступило равное количество студентов, а на факультет C студентов поступило столько же, сколько на A и B вместе. Вероятность того, что студент факультета A сдаст первую сессию, равна 0.8. Для студента факультета B эта вероятность равна 0.7, а для студента факультета C - 0.9. Студент сдал первую сессию. Какова вероятность, что он учится: a). на факультете A б). на факультете B в). на факультете C?

# %%
a=1
b=1
c=2
lambdaA=0.8*1
lambdaB=0.7*1
lambdaC=0.9*2
p=lambdaA+lambdaB+lambdaC
print('студент с факультета A',lambdaA/p)
print('студент с факультета B',lambdaB/p)
print('студент с факультета C',lambdaC/p)
print('проверка',lambdaA/p+lambdaB/p+lambdaC/p)
# Out:
# студент с факультета A 0.24242424242424246
# студент с факультета B 0.21212121212121213
# студент с факультета C 0.5454545454545455
# проверка 1.0

# %% [markdown]
#     Устройство состоит из трех деталей. Для первой детали вероятность выйти из строя в первый месяц равна 0.1, для второй - 0.2, для третьей - 0.25. Какова вероятность того, что в первый месяц выйдут из строя: а). все детали б). только две детали в). хотя бы одна деталь г). от одной до двух деталей?

# %%
p1=0.1
p2=0.2
p3=0.25
all_ = p1*p2*p3
two = p1*p2*(1-p3) + p1*(1-p2)*p3 + (1-p1)*p2*p3
one = p1*(1-p2)*(1-p3) + (1-p1)*p2*(1-p3) + (1-p1)*(1-p2)*p3
print('за месяц сломаются все детали',all_)
print('только две', two)
print('хотя бы одна',1-(1-p1)*(1-p2)*(1-p3)) # 0.9 показывает, что первая деталь работает и по аналогии для ост дет
print('от одной до двух деталей вариант первый', two + one)
# Out:
# за месяц сломаются все детали 0.005000000000000001
# только две 0.08000000000000002
# хотя бы одна 0.45999999999999996
# от одной до двух деталей вариант первый 0.455
